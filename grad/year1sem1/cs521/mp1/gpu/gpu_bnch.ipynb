# %%
from google.colab import drive
drive.mount('/content/drive/')
# %cd "/content/drive/My Drive/CS521/mp1/gpu/build"
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).
# /content/drive/My Drive/CS521/mp1/gpu/build

# %%
# !pip3 install nvcc4jupyter

# %%
# %load_ext nvcc4jupyter
# Out:
# Detected platform "Colab". Running its setup...
# Source files will be saved in "/tmp/tmpf4ny7bmn".

# %%
# %%cuda
# #include <stdio.h>
# int main(void)
# {
#     printf("Hello world.");
# }
# Out:
# Hello world.

# %%
# !git clone https://github.com/CS521-ml-compilers/mp1.git

# %% [markdown]
# ### COMPILE & RUN

# %%
# Force to point to g++-11 compiler
# !cmake -D CMAKE_CUDA_HOST_COMPILER=/usr/bin/g++-11 .. && make
# Out:
# -- Configuring done (0.0s)
# -- Generating done (0.3s)
# -- Build files have been written to: /content/drive/MyDrive/CS521/mp1/gpu/build
# [-50%] Building CUDA object CMakeFiles/mp1_gpu.dir/gemm_gpu.cu.o
# [  0%] Linking CUDA executable mp1_gpu
# [  0%] Built target mp1_gpu

# %%
# !./mp1_gpu 100 100 100
# Out:
# checking gemm_gpu_o3
# Time taken for GEMM (GPU, gemm_gpu_o3): 0.0201536ms

# %%
# !./mp1_gpu 500 500 500
# Out:
# checking gemm_gpu_o3
# Time taken for GEMM (GPU, gemm_gpu_o3): 0.629971ms

# %%
# !./mp1_gpu 1000 1000 1000
# Out:
# checking gemm_gpu_o3
# Time taken for GEMM (GPU, gemm_gpu_o3): 4.77136ms

# %%
# !./mp1_gpu 5000 5000 5000
# Out:
# checking gemm_gpu_o3
# Time taken for GEMM (GPU, gemm_gpu_o3): 236.931ms

# %%
# !./mp1_gpu 10000 10000 10000
# Out:
# checking gemm_gpu_o3
# Time taken for GEMM (GPU, gemm_gpu_o3): 1944.22ms
